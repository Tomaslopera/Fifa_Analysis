# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Preprocesamiento de datos

# %%
df = pd.read_csv('../Fifa Data Analysis/Datasets/2021/fifa21 raw data v2.csv')
df
# Out:
# /var/folders/ph/kk5ffp952hx0h94c23f3_n7r0000gn/T/ipykernel_64327/1841480189.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Fifa Data Analysis/Datasets/2021/fifa21 raw data v2.csv')
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %% [markdown]
# #### Eliminación de columnas innecesarias

# %%
df = df.drop(columns=['ID', 'photoUrl', 'playerUrl'])
df
# Out:
#                     Name                      LongName Nationality  Age  ↓OVA  \
# 0               L. Messi                  Lionel Messi   Argentina   33    93
# 1      Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35    92
# 2               J. Oblak                     Jan Oblak    Slovenia   27    91
# 3           K. De Bruyne               Kevin De Bruyne     Belgium   29    91
# 4              Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28    91
# ...                  ...                           ...         ...  ...   ...
# 18974             Xia Ao                        Ao Xia    China PR   21    47
# 18975           B. Hough                     Ben Hough     England   17    47
# 18976        R. McKinley                Ronan McKinley     England   18    47
# 18977       Wang Zhen'ao                  Zhen'ao Wang    China PR   20    47
# 18978          Zhou Xiao                     Xiao Zhou    China PR   21    47
#
# ...

# %% [markdown]
# #### Modificación de nombre OVERALL

# %%
df['Overall'] = df['↓OVA']
df = df.drop(columns=['↓OVA'])
df
# Out:
#                     Name                      LongName Nationality  Age  POT  \
# 0               L. Messi                  Lionel Messi   Argentina   33   93
# 1      Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35   92
# 2               J. Oblak                     Jan Oblak    Slovenia   27   93
# 3           K. De Bruyne               Kevin De Bruyne     Belgium   29   91
# 4              Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28   91
# ...                  ...                           ...         ...  ...  ...
# 18974             Xia Ao                        Ao Xia    China PR   21   55
# 18975           B. Hough                     Ben Hough     England   17   67
# 18976        R. McKinley                Ronan McKinley     England   18   65
# 18977       Wang Zhen'ao                  Zhen'ao Wang    China PR   20   57
# 18978          Zhou Xiao                     Xiao Zhou    China PR   21   57
#
# ...

# %% [markdown]
# #### Eliminación de columna LongName

# %%
df = df.drop(columns=['LongName'])
df
# Out:
#                     Name Nationality  Age  POT                         Club  \
# 0               L. Messi   Argentina   33   93         \n\n\n\nFC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             \n\n\n\nJuventus
# 2               J. Oblak    Slovenia   27   93      \n\n\n\nAtlético Madrid
# 3           K. De Bruyne     Belgium   29   91      \n\n\n\nManchester City
# 4              Neymar Jr      Brazil   28   91  \n\n\n\nParis Saint-Germain
# ...                  ...         ...  ...  ...                          ...
# 18974             Xia Ao    China PR   21   55           \n\n\n\nWuhan Zall
# 18975           B. Hough     England   17   67      \n\n\n\nOldham Athletic
# 18976        R. McKinley     England   18   65           \n\n\n\nDerry City
# 18977       Wang Zhen'ao    China PR   20   57     \n\n\n\nDalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     \n\n\n\nDalian YiFang FC
#
# ...

# %% [markdown]
# #### Limpieza de datos Club

# %%
df['Club'] = df['Club'].str.replace('\n\n\n\n', '')
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions Height Weight Preferred Foot  ...     D/W   IR  \
# ...

# %% [markdown]
# #### Modificación de datos Contract

# %%
df['Contract'] = df['Contract'].str.replace('~', '-')
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions Height Weight Preferred Foot  ...     D/W   IR  \
# ...

# %% [markdown]
# #### Modificación de formatos Height y Weight

# %%
df['Height'] = df['Height'].str.replace('cm', '')
df['Weight'] = df['Weight'].str.replace('kg', '')
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions Height Weight Preferred Foot  ...     D/W   IR  \
# ...

# %%
df = df.rename(columns={'Height': 'Height (cm)', 'Weight': 'Weight (kg)'})
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions Height (cm) Weight (kg) Preferred Foot  ...  \
# ...

# %%
df['Height (cm)'] = pd.to_numeric(df['Height (cm)'], errors='coerce')
df['Weight (kg)'] = pd.to_numeric(df['Weight (kg)'], errors='coerce')
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions  Height (cm)  Weight (kg) Preferred Foot  ...  \
# ...

# %% [markdown]
# #### Identificación

# %%
df.columns
# Out:
# Index(['Name', 'Nationality', 'Age', 'POT', 'Club', 'Contract', 'Positions',
#        'Height (cm)', 'Weight (kg)', 'Preferred Foot', 'BOV', 'Best Position',
#        'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
# ...

# %%
df['POT']
# Out:
# 0        93
# 1        92
# 2        93
# 3        91
# 4        91
#          ..
# 18974    55
# 18975    67
# 18976    65
# 18977    57
# 18978    57
# Name: POT, Length: 18979, dtype: int64

# %% [markdown]
# #### Conversión de Joined Date a DATETIME

# %%
df = df.rename(columns={'Joined': 'Joined Date'})
df['Joined Date'] = pd.to_datetime(df['Joined Date'], errors='coerce')
df['Joined Date']
# Out:
# 0       2004-07-01
# 1       2018-07-10
# 2       2014-07-16
# 3       2015-08-30
# 4       2017-08-03
#            ...
# 18974   2018-07-13
# 18975   2020-08-01
# 18976   2019-03-08
# 18977   2020-09-22
# 18978   2019-07-29
# Name: Joined Date, Length: 18979, dtype: datetime64[ns]

# %% [markdown]
# #### Conversión de Loan Date a DATETIME

# %%
df['Loan Date End'] = pd.to_datetime(df['Loan Date End'], errors='coerce')
df['Loan Date End']
# Out:
# 0       NaT
# 1       NaT
# 2       NaT
# 3       NaT
# 4       NaT
#          ..
# 18974   NaT
# 18975   NaT
# 18976   NaT
# 18977   NaT
# 18978   NaT
# Name: Loan Date End, Length: 18979, dtype: datetime64[ns]

# %% [markdown]
# #### Conversión de Value a INT

# %%
df['Value'] = df['Value'].str.replace('€', '')
if df['Value'].str.contains('.').any():
    df['Value'] = df['Value'].str.replace('M', '00000')
    df['Value'] = df['Value'].str.replace('K', '000')
else:
    df['Value'] = df['Value'].str.replace('M', '000000')
    df['Value'] = df['Value'].str.replace('K', '000')

df['Value'] = df['Value'].str.replace('.', '')

df = df.rename(columns={'Value': 'Value (€)'})
df['Value (€)'] = pd.to_numeric(df['Value (€)'], errors='coerce')
df['Value (€)']
# Out:
# 0        103500000
# 1          6300000
# 2         12000000
# 3         12900000
# 4         13200000
#            ...
# 18974       100000
# 18975       130000
# 18976       120000
# 18977       100000
# 18978       100000
# Name: Value (€), Length: 18979, dtype: int64

# %% [markdown]
# #### Conversión de Wage a INT

# %%
df['Wage'] = df['Wage'].str.replace('€', '')
df['Wage'] = df['Wage'].str.replace('K', '000')
df['Wage'] = pd.to_numeric(df['Wage'], errors='coerce')
df = df.rename(columns={'Wage': 'Wage (€)'})
df['Wage (€)']
# Out:
# 0        560000
# 1        220000
# 2        125000
# 3        370000
# 4        270000
#           ...
# 18974      1000
# 18975       500
# 18976       500
# 18977      2000
# 18978      1000
# Name: Wage (€), Length: 18979, dtype: int64

# %% [markdown]
# #### Conversión de Release Clause a INT

# %%
df['Release Clause'] = df['Release Clause'].str.replace('€', '')
if df['Release Clause'].str.contains('.').any():
    df['Release Clause'] = df['Release Clause'].str.replace('M', '00000')
    df['Release Clause'] = df['Release Clause'].str.replace('K', '000')
else:
    df['Release Clause'] = df['Release Clause'].str.replace('M', '000000')
    df['Release Clause'] = df['Release Clause'].str.replace('K', '000')

df['Release Clause'] = df['Release Clause'].str.replace('.', '')

df = df.rename(columns={'Release Clause': 'Release Clause (€)'})
df['Release Clause (€)'] = pd.to_numeric(df['Release Clause (€)'], errors='coerce')
df['Release Clause (€)']
# Out:
# 0        138400000
# 1         75900000
# 2        159400000
# 3         16100000
# 4        166500000
#            ...
# 18974        70000
# 18975       165000
# 18976       131000
# 18977        88000
# 18978        79000
# Name: Release Clause (€), Length: 18979, dtype: int64

# %% [markdown]
# #### Modificación estrellas

# %%
df['W/F'] = df['W/F'].str.replace('★', '')
df['SM'] = df['SM'].str.replace(' ★', '')
df['IR'] = df['IR'].str.replace(' ★', '')

df = df.rename(columns={'W/F': 'W/F (★)', 'SM': 'SM (★)', 'IR': 'IR (★)'})
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions  Height (cm)  Weight (kg) Preferred Foot  ...  \
# ...

# %% [markdown]
# #### Modificación A/W y D/W

# %%
df['A/W'] = df['A/W'].replace({'Low': 'L', 'Medium': 'M', 'High': 'H'})
df['D/W'] = df['D/W'].replace({'Low': 'L', 'Medium': 'M', 'High': 'H'})
df
# Out:
#                     Name Nationality  Age  POT                 Club  \
# 0               L. Messi   Argentina   33   93         FC Barcelona
# 1      Cristiano Ronaldo    Portugal   35   92             Juventus
# 2               J. Oblak    Slovenia   27   93      Atlético Madrid
# 3           K. De Bruyne     Belgium   29   91      Manchester City
# 4              Neymar Jr      Brazil   28   91  Paris Saint-Germain
# ...                  ...         ...  ...  ...                  ...
# 18974             Xia Ao    China PR   21   55           Wuhan Zall
# 18975           B. Hough     England   17   67      Oldham Athletic
# 18976        R. McKinley     England   18   65           Derry City
# 18977       Wang Zhen'ao    China PR   20   57     Dalian YiFang FC
# 18978          Zhou Xiao    China PR   21   57     Dalian YiFang FC
#
#           Contract   Positions  Height (cm)  Weight (kg) Preferred Foot  ...  \
# ...

# %% [markdown]
# #### Eliminar atributos (Ya se relizó un Análisis de atributos en fifa 24)

# %%
df_cleaned = df.copy()
df_cleaned.columns
# Out:
# Index(['Name', 'Nationality', 'Age', 'POT', 'Club', 'Contract', 'Positions',
#        'Height (cm)', 'Weight (kg)', 'Preferred Foot', 'BOV', 'Best Position',
#        'Joined Date', 'Loan Date End', 'Value (€)', 'Wage (€)',
#        'Release Clause (€)', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F (★)', 'SM (★)', 'A/W', 'D/W', 'IR (★)', 'PAC', 'SHO',
# ...

# %%
df_cleaned = df_cleaned.drop(columns=['Attacking', 'Crossing', 'Finishing',
       'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
       'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
       'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
       'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
       'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
       'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
       'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
       'Base Stats', 'A/W', 'D/W', 'Hits', 'POT', 'BOV', 'IR (★)', 'PAC', 'SHO',
       'PAS', 'DRI', 'DEF', 'PHY'])

# %% [markdown]
# ## Análisis

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                18979 non-null  object
#  1   Nationality         18979 non-null  object
#  2   Age                 18979 non-null  int64
#  3   Club                18979 non-null  object
#  4   Contract            18979 non-null  object
#  5   Positions           18979 non-null  object
#  6   Height (cm)         18939 non-null  float64
#  7   Weight (kg)         18939 non-null  float64
#  8   Preferred Foot      18979 non-null  object
#  9   Best Position       18979 non-null  object
#  10  Joined Date         18979 non-null  datetime64[ns]
#  11  Loan Date End       1013 non-null   datetime64[ns]
#  12  Value (€)           18979 non-null  int64
#  13  Wage (€)            18979 non-null  int64
#  14  Release Clause (€)  18979 non-null  int64
# ...

# %%
data = df_cleaned.groupby('Club')['Value (€)'].sum().sort_values(ascending=False).reset_index().head(20)

top20 = df_cleaned[df_cleaned['Club'].isin(data['Club'])]

plt.figure(figsize=(12, 8))
sns.barplot(data=data, x='Value (€)', y='Club', palette='viridis', hue='Value (€)')
plt.title('Top 20 Equipos por el valor total de sus jugadores')
plt.xlabel('Total Player Value (€)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
data = top20.groupby('Club')['Height (cm)'].mean().sort_values(ascending=False).reset_index().head(20)

plt.figure(figsize=(12, 8))
sns.barplot(data=data, x='Height (cm)', y='Club', palette='viridis', hue='Height (cm)')
plt.title('Altura media de los jugadores de los 20 equipos con mayor valor total')
plt.xlabel('Average Height (cm)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
data = top20.groupby('Club')['Weight (kg)'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(12, 8))
sns.barplot(data=data, x='Weight (kg)', y='Club', palette='viridis', hue='Weight (kg)')
plt.title('Peso medio de los jugadores de los 20 equipos con mayor valor total')
plt.xlabel('Average Weight (kg)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
data = df_cleaned.groupby('Club')['Release Clause (€)'].sum().sort_values(ascending=False).reset_index().head(20)

plt.figure(figsize=(12, 8))
sns.barplot(data=data, x='Release Clause (€)', y='Club', palette='viridis', hue='Release Clause (€)')
plt.title('Top 20 Equipos por la cláusula de rescisión total de sus jugadores')
plt.xlabel('Total Release Clause (€)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
relacion = top20.melt(id_vars=['Club'], value_vars=['Value (€)', 'Release Clause (€)'], var_name='Tipo', value_name='Valor')

plt.figure(figsize=(12, 8))
sns.barplot(data=relacion, x='Valor', y='Club', hue='Tipo', palette='viridis')
plt.title('Relación entre el valor total de los jugadores y la cláusula de rescisión')
plt.xlabel('Valor (€)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
top20.to_csv('../Fifa Data Analysis/Datasets/2021/New Datasets/PlayersByTop20.csv', index=False)

# %% [markdown]
# #### Artibutos

# %%
df_delanteros = df[df['Best Position'].str.contains('ST|CF|RW|LW|RF|LF')]
top30_delanteros = df_delanteros.sort_values(by='Overall', ascending=False).head(30)

plt.figure(figsize=(12, 8))
sns.barplot(data=top30_delanteros, x='Overall', y='Name', palette='viridis', hue='Overall')
plt.title('Top 30 Delanteros por su valoración')
plt.xlabel('Overall')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10)) 

sns.barplot(data=top30_delanteros, x='PAC', y='Name', palette='viridis', ax=ax[0, 0], hue='PAC')
ax[0, 0].set_title('Velocidad (Pace)')
ax[0, 0].set_ylabel('')
sns.barplot(data=top30_delanteros, x='SHO', y='Name', palette='viridis', ax=ax[0, 1], hue='SHO')
ax[0, 1].set_title('Disparo (Shooting)')
ax[0, 1].set_ylabel('')
sns.barplot(data=top30_delanteros, x='PAS', y='Name', palette='viridis', ax=ax[0, 2], hue='PAS')
ax[0, 2].set_title('Pases (Passing)')
ax[0, 2].set_ylabel('')
sns.barplot(data=top30_delanteros, x='DRI', y='Name', palette='viridis', ax=ax[1, 0], hue='DRI')
ax[1, 0].set_title('Regate (Dribbling)')
ax[1, 0].set_ylabel('')
sns.barplot(data=top30_delanteros, x='DEF', y='Name', palette='viridis', ax=ax[1, 1], hue='DEF')
ax[1, 1].set_title('Defensa (Defending)')
ax[1, 1].set_ylabel('')
sns.barplot(data=top30_delanteros, x='PHY', y='Name', palette='viridis', ax=ax[1, 2], hue='PHY')
ax[1, 2].set_title('Físico (Physicality)')
ax[1, 2].set_ylabel('')

fig.suptitle('Top 30 delanteros con mejor media de estadísticas por atributo', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %%
df_mediocampistas = df[df['Best Position'].str.contains('CM|CDM|CAM|RM|LM')]
top30_mediocampistas = df_mediocampistas.sort_values(by='Overall', ascending=False).head(30)

plt.figure(figsize=(12, 8))
sns.barplot(data=top30_mediocampistas, x='Overall', y='Name', palette='viridis', hue='Overall')
plt.title('Top 30 Mediocampistas por su valoración')
plt.xlabel('Overall')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10))

sns.barplot(data=top30_mediocampistas, x='PAC', y='Name', palette='viridis', ax=ax[0, 0], hue='PAC')
ax[0, 0].set_title('Velocidad (Pace)')
ax[0, 0].set_ylabel('')
sns.barplot(data=top30_mediocampistas, x='SHO', y='Name', palette='viridis', ax=ax[0, 1], hue='SHO')
ax[0, 1].set_title('Disparo (Shooting)')
ax[0, 1].set_ylabel('')
sns.barplot(data=top30_mediocampistas, x='PAS', y='Name', palette='viridis', ax=ax[0, 2], hue='PAS')
ax[0, 2].set_title('Pases (Passing)')
ax[0, 2].set_ylabel('')
sns.barplot(data=top30_mediocampistas, x='DRI', y='Name', palette='viridis', ax=ax[1, 0], hue='DRI')
ax[1, 0].set_title('Regate (Dribbling)')    
ax[1, 0].set_ylabel('')
sns.barplot(data=top30_mediocampistas, x='DEF', y='Name', palette='viridis', ax=ax[1, 1], hue='DEF')
ax[1, 1].set_title('Defensa (Defending)')
ax[1, 1].set_ylabel('')
sns.barplot(data=top30_mediocampistas, x='PHY', y='Name', palette='viridis', ax=ax[1, 2], hue='PHY')
ax[1, 2].set_title('Físico (Physicality)')
ax[1, 2].set_ylabel('')

fig.suptitle('Top 30 mediocampistas con mejor media de estadísticas por atributo', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %%
df_defensas = df[df['Best Position'].str.contains('CB|RB|LB|RWB|LWB')]
top30_defensas = df_defensas.sort_values(by='Overall', ascending=False).head(30)

plt.figure(figsize=(12, 8))
sns.barplot(data=top30_defensas, x='Overall', y='Name', palette='viridis', hue='Overall')
plt.title('Top 30 Defensores por su valoración')
plt.xlabel('Overall')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10))

sns.barplot(data=top30_defensas, x='PAC', y='Name', palette='viridis', ax=ax[0, 0], hue='PAC')
ax[0, 0].set_title('Velocidad (Pace)')
ax[0, 0].set_ylabel('')
sns.barplot(data=top30_defensas, x='SHO', y='Name', palette='viridis', ax=ax[0, 1], hue='SHO')
ax[0, 1].set_title('Disparo (Shooting)')
ax[0, 1].set_ylabel('')
sns.barplot(data=top30_defensas, x='PAS', y='Name', palette='viridis', ax=ax[0, 2], hue='PAS')
ax[0, 2].set_title('Pases (Passing)')
ax[0, 2].set_ylabel('')
sns.barplot(data=top30_defensas, x='DRI', y='Name', palette='viridis', ax=ax[1, 0], hue='DRI')
ax[1, 0].set_title('Regate (Dribbling)')
ax[1, 0].set_ylabel('')
sns.barplot(data=top30_defensas, x='DEF', y='Name', palette='viridis', ax=ax[1, 1], hue='DEF')
ax[1, 1].set_title('Defensa (Defending)')
ax[1, 1].set_ylabel('')
sns.barplot(data=top30_defensas, x='PHY', y='Name', palette='viridis', ax=ax[1, 2], hue='PHY')
ax[1, 2].set_title('Físico (Physicality)')
ax[1, 2].set_ylabel('')

fig.suptitle('Top 30 defensores con mejor media de estadísticas por atributo', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %%
df_arqueros = df[df['Best Position'].str.contains('GK')]
top30_arqueros = df_arqueros.sort_values(by='Overall', ascending=False).head(30)

plt.figure(figsize=(12, 8))
sns.barplot(data=top30_arqueros, x='Overall', y='Name', palette='viridis', hue='Overall')
plt.title('Top 30 Arqueros por su valoración')
plt.xlabel('Overall')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
top30_delanteros[['Name', 'Nationality', 'Club', 'Overall', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY']].to_csv('../Fifa Data Analysis/Datasets/2021/New Datasets/Delanteros_21.csv', index=False)
top30_mediocampistas[['Name', 'Nationality', 'Club', 'Overall', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY']].to_csv('../Fifa Data Analysis/Datasets/2021/New Datasets/Mediocampistas_21.csv', index=False)
top30_defensas[['Name', 'Nationality', 'Club', 'Overall', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY']].to_csv('../Fifa Data Analysis/Datasets/2021/New Datasets/Defensores_21.csv', index=False)
top30_arqueros[['Name', 'Nationality', 'Club', 'Overall', 'GK']].to_csv('../Fifa Data Analysis/Datasets/2021/New Datasets/Arqueros_21.csv', index=False)
